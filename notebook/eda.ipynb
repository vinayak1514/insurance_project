# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('D:\\study\\Data_science\\code\machine_learning\\insurance_project\\notebook\\insurance.csv')

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df_copy.shape
# Out:
# (1338, 7)

# %%
df_copy.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df_copy.nunique()
# Out:
# age           47
# sex            2
# bmi          275
# children       6
# smoker         2
# region         4
# expenses    1337
# dtype: int64

# %%
df_copy.describe().T
# Out:
#            count          mean           std      min        25%      50%  \
# age       1338.0     39.207025     14.049960    18.00    27.0000    39.00
# bmi       1338.0     30.665471      6.098382    16.00    26.3000    30.40
# children  1338.0      1.094918      1.205493     0.00     0.0000     1.00
# expenses  1338.0  13270.422414  12110.011240  1121.87  4740.2875  9382.03
#
#                 75%       max
# age          51.000     64.00
# bmi          34.700     53.10
# children      2.000      5.00
# expenses  16639.915  63770.43

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ## report
#
# * Data having 1338 rows and 7 columns
# * Null is not present in the dataset
# * sex, smoker, region are categorical feature
# * 'age', 'bmi', 'children', 'expenses' are numerical feature

# %%
categorical_columns = [i for i in df.columns if df_copy[i].dtype == 'O']
numerical_columns = [i for i in df.columns if df_copy[i].dtype != 'O']

# %%
df_copy[numerical_columns].corr()
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %%
for col in df_copy[numerical_columns]:
        j=1
        plt.figure(figsize=(15,5))
        plt.subplot(1,4,j)
        sns.distplot(df_copy[col],hist=False)
        plt.show()
        j+=1

# %%
sns.pairplot(df_copy[numerical_columns])

# %%
df_copy['expenses'].skew()
# Out:
# 1.51587966289798

# %%
import scipy.stats as stats
import pylab
stats.probplot(df_copy['children'], dist="norm", plot=pylab)
# Out:
# ((array([-3.28061069, -3.02161974, -2.87748242, ...,  2.87748242,
#           3.02161974,  3.28061069]),
#   array([0, 0, 0, ..., 5, 5, 5], dtype=int64)),
#  (1.0962307471439767, 1.0949177877429002, 0.9077457693863356))

# %%
plt.figure(figsize=(15,5))
plt.subplot(141)
sns.boxplot(df_copy['age'])
plt.subplot(142)
sns.boxplot(df_copy['bmi'])
plt.subplot(143)
sns.boxplot(df_copy['children'])
plt.subplot(144)
sns.boxplot(df_copy['expenses'])
# Out:
# <Axes: ylabel='expenses'>
